# %%
import pandas as pd
import numpy as np
food_choices=pd.read_csv('/Users/shreyaravichandiran/Documents/GitHub/Navigate-and-Clean-data-using-Python/food_coded.csv')
food_choices.head() #top 5 rows of the data set
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
food_choices.info() #details and info of 20 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
food_choices.isna().sum() #isna() shows the null values sum() adds all the null values in the rows
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         26
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
food_choices.shape #(row,column)
# Out:
# (125, 61)

# %%
data=food_choices.copy() #copying data for modification, do not use real data for modification

# %%
#remove white spaces from columns
data.columns = data.columns.str.strip() #converts into strings and forms as lists
data.columns.tolist()
# Out:
# ['GPA',
#  'Gender',
#  'breakfast',
#  'calories_chicken',
#  'calories_day',
#  'calories_scone',
#  'coffee',
#  'comfort_food',
#  'comfort_food_reasons',
#  'comfort_food_reasons_coded',
#  'cook',
#  'comfort_food_reasons_coded.1',
#  'cuisine',
#  'diet_current',
#  'diet_current_coded',
#  'drink',
#  'eating_changes',
#  'eating_changes_coded',
#  'eating_changes_coded1',
#  'eating_out',
#  'employment',
#  'ethnic_food',
#  'exercise',
#  'father_education',
#  'father_profession',
#  'fav_cuisine',
#  'fav_cuisine_coded',
#  'fav_food',
#  'food_childhood',
#  'fries',
#  'fruit_day',
#  'grade_level',
#  'greek_food',
#  'healthy_feeling',
#  'healthy_meal',
#  'ideal_diet',
#  'ideal_diet_coded',
#  'income',
#  'indian_food',
#  'italian_food',
#  'life_rewarding',
#  'marital_status',
#  'meals_dinner_friend',
#  'mother_education',
#  'mother_profession',
#  'nutritional_check',
#  'on_off_campus',
#  'parents_cook',
#  'pay_meal_out',
#  'persian_food',
# ...

# %%
# Removing unwanted data in place
data.drop(['GPA','Gender', 'comfort_food_reasons_coded.1', 'eating_changes_coded1','employment','father_education',
'father_profession', 'grade_level','income','mother_profession','mother_education', 'ethnic_food', 'on_off_campus','sports', 
'type_sports', 'marital_status'], axis = 1, inplace = True)
data.columns.tolist()
# Out:
# ['breakfast',
#  'calories_chicken',
#  'calories_day',
#  'calories_scone',
#  'coffee',
#  'comfort_food',
#  'comfort_food_reasons',
#  'comfort_food_reasons_coded',
#  'cook',
#  'cuisine',
#  'diet_current',
#  'diet_current_coded',
#  'drink',
#  'eating_changes',
#  'eating_changes_coded',
#  'eating_out',
#  'exercise',
#  'fav_cuisine',
#  'fav_cuisine_coded',
#  'fav_food',
#  'food_childhood',
#  'fries',
#  'fruit_day',
#  'greek_food',
#  'healthy_feeling',
#  'healthy_meal',
#  'ideal_diet',
#  'ideal_diet_coded',
#  'indian_food',
#  'italian_food',
#  'life_rewarding',
#  'meals_dinner_friend',
#  'nutritional_check',
#  'parents_cook',
#  'pay_meal_out',
#  'persian_food',
#  'self_perception_weight',
#  'soup',
#  'thai_food',
#  'tortilla_calories',
#  'turkey_calories',
#  'veggies_day',
#  'vitamins',
#  'waffle_calories',
#  'weight']

# %%
#remove code that doesn't have any 
data.dropna(subset=['calories_day','weight'], inplace=True)
data.isna().sum()
# Out:
# breakfast                      0
# calories_chicken               0
# calories_day                   0
# calories_scone                 1
# coffee                         0
# comfort_food                   0
# comfort_food_reasons           1
# comfort_food_reasons_coded    15
# cook                           1
# cuisine                       13
# diet_current                   0
# diet_current_coded             0
# drink                          2
# eating_changes                 1
# eating_changes_coded           0
# eating_out                     0
# exercise                       8
# fav_cuisine                    1
# fav_cuisine_coded              0
# fav_food                       1
# food_childhood                 0
# fries                          0
# fruit_day                      0
# greek_food                     0
# healthy_feeling                0
# healthy_meal                   0
# ideal_diet                     0
# ideal_diet_coded               0
# ...

# %%
# Remove rows where user didn't have any important details
missing_data = data[(data['self_perception_weight'].isna()) & (data['nutritional_check'].isna())]
data.drop(missing_data.index, inplace=True)

# Remove favorite cusinie column
data.drop(columns=['fav_cuisine'], axis=1, inplace=True)

# %%
data.drop(['vitamins'],axis = 1, inplace = True)
data.head(10)
# Out:
#     breakfast  calories_chicken  calories_day  calories_scone  coffee  \
# 1           1               610           3.0           420.0       2
# 2           1               720           4.0           420.0       2
# 3           1               430           3.0           420.0       2
# 4           1               720           2.0           420.0       2
# 5           1               610           3.0           980.0       2
# 6           1               610           3.0           420.0       2
# 7           1               720           3.0           420.0       1
# 9           1               430           3.0           315.0       2
# 10          1               610           3.0           980.0       2
# 11          1               720           4.0           420.0       2
#
#                                          comfort_food  \
# 1                         chocolate, chips, ice cream
# 2                     frozen yogurt, pizza, fast food
# ...

# %%
df = pd.DataFrame(columns= ['weight', 'nutritional_check', 'healthy_meal','comfort_food_reasons', 'eating_changes','diet_current','veggies_day','waffle_calories'])
df['weight'] = data['weight']
df['nutritional_check'] = data['nutritional_check']
df['waffle_calories'] = data['waffle_calories']
df['healthy_meal'] = data['healthy_meal']
df['comfort_food_reasons'] = data['comfort_food_reasons']
df['eating_changes'] = data['eating_changes']
df['diet_current'] = data['diet_current']
df['veggies_day'] = data['veggies_day']
df.head()
#creating a dataframe and keeping only the required data
# Out:
#                      weight  nutritional_check  \
# 1                       155                  4
# 2  I'm not answering this.                   4
# 3             Not sure, 240                  2
# 4                       190                  3
# 5                       190                  1
#
#                                         healthy_meal  \
# 1  Grains, Veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3           Fresh fruits& vegetables, organic meats
# 4  A lean protein such as grilled chicken, green ...
# 5       Requires veggies, fruits and a cooked meal.
#
#                                 comfort_food_reasons  \
# 1                               Stress, bored, anger
# 2                                    stress, sadness
# 3                                            Boredom
# 4                         Stress, boredom, cravings
# 5  None, i don't eat comfort food. I just eat whe...
#
# ...

# %%
df = df.drop_duplicates() # remove duplicates

# %%
print(df.isnull().sum())  # check for missing values
# drop rows with any missing values
df = df.dropna()
# Out:
# weight                  0
# nutritional_check       0
# healthy_meal            0
# comfort_food_reasons    1
# eating_changes          1
# diet_current            0
# veggies_day             0
# waffle_calories         0
# dtype: int64

# %%
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['waffle_calories'] = pd.to_numeric(df['waffle_calories'], errors='coerce')
df['veggies_day'] = pd.to_numeric(df['veggies_day'], errors='coerce')
df.head(10)
#converting into similar datatype
# Out:
#     weight  nutritional_check  \
# 1    155.0                  4
# 2      NaN                  4
# 3      NaN                  2
# 4    190.0                  3
# 5    190.0                  1
# 6    180.0                  4
# 7    137.0                  4
# 9    125.0                  5
# 10   116.0                  2
# 11   110.0                  5
#
#                                          healthy_meal  \
# 1   Grains, Veggies, (more of grains and veggies),...
# 2   usually includes natural ingredients; nonproce...
# 3            Fresh fruits& vegetables, organic meats
# 4   A lean protein such as grilled chicken, green ...
# 5        Requires veggies, fruits and a cooked meal.
# 6          Protein, vegetables, fruit, and some carbs
# 7   A healthy meal has a piece of meat followed by...
# 9           Chicken and rice with a side of veggies.
# 10                              Chicken, and veggies
# 11        lean protein, veggies, fruit, complex carbs
#
# ...

# %%
df['healthy_meal'] = df['healthy_meal'].str.strip().str.lower()
df['comfort_food_reasons'] = df['comfort_food_reasons'].str.strip().str.lower()
df['eating_changes'] = df['eating_changes'].str.strip().str.lower()
df['diet_current'] = df['diet_current'].str.strip().str.lower()
#standardize text

# %%
# display cleaned data
print(df.head())
# Out:
#    weight  nutritional_check  \
# 1   155.0                  4
# 2     NaN                  4
# 3     NaN                  2
# 4   190.0                  3
# 5   190.0                  1
#
#                                         healthy_meal  \
# 1  grains, veggies, (more of grains and veggies),...
# 2  usually includes natural ingredients; nonproce...
# 3            fresh fruits& vegetables, organic meats
# 4  a lean protein such as grilled chicken, green ...
# 5        requires veggies, fruits and a cooked meal.
#
#                                 comfort_food_reasons  \
# 1                               stress, bored, anger
# 2                                    stress, sadness
# 3                                            boredom
# 4                          stress, boredom, cravings
# 5  none, i don't eat comfort food. i just eat whe...
#
#                                       eating_changes  \
# 1                         i eat out more than usual.
# ...
